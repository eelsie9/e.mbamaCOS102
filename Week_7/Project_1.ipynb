# %%
# For First 7 rows in Top Apps in Google Play
import pandas as pd
 
data = pd.read_csv("Top-Apps-in-Google-Play.csv")
df = data.iloc[:7]

df
# Out:
#    Unnamed: 0                          App Name  \
# 0           1              Google Play services
# 1           2                           YouTube
# 2           3                            Google
# 3           4  Google Maps - Navigate & Explore
# 4           5             Google Text-to-Speech
# 5           6      Google Chrome: Fast & Secure
# 6           7                             Gmail
#
#                                     App Id                 Category  \
# 0                   com.google.android.gms                    Tools
# 1               com.google.android.youtube  Video Players & Editors
# 2  com.google.android.googlequicksearchbox                    Tools
# 3             com.google.android.apps.maps           Travel & Local
# 4                   com.google.android.tts                    Tools
# 5                       com.android.chrome            Communication
# 6                    com.google.android.gm            Communication
#
# ...

# %%
# For First 7 rows in Cryptocurrency Predict Artificial Intelligence V3
import pandas as pd
 
data = pd.read_csv("BTC_DATA_V3.0.csv")
df = data.iloc[:7]

df
# Out:
#         Date    Price     Open     High      Low     Vol. Change %
# 0  25-Mar-22  44331.0  44013.0  45112.0  43622.0  494.09M    0.72%
# 1  24-Mar-22  44013.0  42911.0  44251.0  42658.0  491.66M    2.57%
# 2  23-Mar-22  42912.0  42373.0  43027.0  41795.0  433.96M    1.27%
# 3  22-Mar-22  42373.0  41022.0  43327.9  40893.0  537.06M    3.29%
# 4  21-Mar-22  41022.0  41282.0  41532.0  40530.0  406.62M   -0.62%
# 5  20-Mar-22  41276.0  42241.0  42301.0  40922.0  308.45M   -2.27%
# 6  19-Mar-22  42233.0  41768.0  42386.0  41529.6  224.59M    1.11%

# %%
# For First 7 rows in Programming Languages Trend Over Time
import pandas as pd
 
data = pd.read_csv("programming language trend over time.csv")
df = data.iloc[:7]

df
# Out:
#         Week  Python  Java  C++
# 0  4/21/2019      55    55   18
# 1  4/28/2019      52    50   16
# 2   5/5/2019      56    56   17
# 3  5/12/2019      56    61   18
# 4  5/19/2019      57    56   17
# 5  5/26/2019      55    57   17
# 6   6/2/2019      54    58   15

# %%
# For First 3 rows in Top Apps in Google Play
import pandas as pd
 
data = pd.read_csv("Top-Apps-in-Google-Play.csv")
df = data.iloc[:3]

df
# Out:
#    Unnamed: 0              App Name                                   App Id  \
# 0           1  Google Play services                   com.google.android.gms
# 1           2               YouTube               com.google.android.youtube
# 2           3                Google  com.google.android.googlequicksearchbox
#
#                   Category Developer Id  \
# 0                    Tools   Google LLC
# 1  Video Players & Editors   Google LLC
# 2                    Tools   Google LLC
#
#                                    Developer Website  \
# 0  https://developers.google.com/android/google-p...
# 1  https://support.google.com/youtube/topic/24225...
# 2               https://www.google.com/search/about/
#
#                 Developer Email Content Rating  Ad Supported  In App Purchases
# 0          apps-help@google.com       Everyone         False             False
# 1  ytandroid-support@google.com           Teen          True             False
# ...

# %%
# For First 3 rows in Cryptocurrency Predict Artificial Intelligence V3
import pandas as pd
 
data = pd.read_csv("BTC_DATA_V3.0.csv")
df = data.iloc[:3]

df
# Out:
#         Date    Price     Open     High      Low     Vol. Change %
# 0  25-Mar-22  44331.0  44013.0  45112.0  43622.0  494.09M    0.72%
# 1  24-Mar-22  44013.0  42911.0  44251.0  42658.0  491.66M    2.57%
# 2  23-Mar-22  42912.0  42373.0  43027.0  41795.0  433.96M    1.27%

# %%
# For First 3 rows in Programming Languages Trend Over Time
import pandas as pd
 
data = pd.read_csv("programming language trend over time.csv")
df = data.iloc[:3]

df
# Out:
#         Week  Python  Java  C++
# 0  4/21/2019      55    55   18
# 1  4/28/2019      52    50   16
# 2   5/5/2019      56    56   17

# %%
# For first row and header in Top Apps in Google Play
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("Top-Apps-In-Google-Play.csv")
df = data.head(1)

df
# Out:
#    Unnamed: 0              App Name                  App Id Category  \
# 0           1  Google Play services  com.google.android.gms    Tools
#
#   Developer Id                                  Developer Website  \
# 0   Google LLC  https://developers.google.com/android/google-p...
#
#         Developer Email Content Rating  Ad Supported  In App Purchases
# 0  apps-help@google.com       Everyone         False             False

# %%
# For first row and header in Cryptocurrency Predict Artificial Intelligence V3
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("BTC_DATA_V3.0.csv")
df = data.head(1)

df
# Out:
#         Date    Price     Open     High      Low     Vol. Change %
# 0  25-Mar-22  44331.0  44013.0  45112.0  43622.0  494.09M    0.72%

# %%
# For first row and header in Programming Languages Trend Over Time
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("programming language trend over time.csv")
df = data.head(1)

df
# Out:
#         Week  Python  Java  C++
# 0  4/21/2019      55    55   18
